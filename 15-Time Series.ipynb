# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data" data-toc-modified-id="Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Project-description" data-toc-modified-id="Project-description-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Project description</a></span></li><li><span><a href="#Data-description" data-toc-modified-id="Data-description-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data description</a></span></li><li><span><a href="#Library-imports-and-project-environment-setup" data-toc-modified-id="Library-imports-and-project-environment-setup-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Library imports and project environment setup</a></span></li><li><span><a href="#CSV-file-read" data-toc-modified-id="CSV-file-read-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>CSV file read</a></span></li><li><span><a href="#General-info" data-toc-modified-id="General-info-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>General info</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#New-features" data-toc-modified-id="New-features-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>New features</a></span></li></ul></li><li><span><a href="#Model" data-toc-modified-id="Model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Model</a></span><ul class="toc-item"><li><span><a href="#Splitting" data-toc-modified-id="Splitting-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Splitting</a></span></li><li><span><a href="#Standard-scaling" data-toc-modified-id="Standard-scaling-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Standard scaling</a></span></li><li><span><a href="#Model-selection-by-RMSE" data-toc-modified-id="Model-selection-by-RMSE-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Model selection by RMSE</a></span><ul class="toc-item"><li><span><a href="#Baseline" data-toc-modified-id="Baseline-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Baseline</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Base" data-toc-modified-id="Base-2.3.2.1"><span class="toc-item-num">2.3.2.1&nbsp;&nbsp;</span>Base</a></span></li><li><span><a href="#Tuned" data-toc-modified-id="Tuned-2.3.2.2"><span class="toc-item-num">2.3.2.2&nbsp;&nbsp;</span>Tuned</a></span></li></ul></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#Base" data-toc-modified-id="Base-2.3.3.1"><span class="toc-item-num">2.3.3.1&nbsp;&nbsp;</span>Base</a></span></li><li><span><a href="#Tuned" data-toc-modified-id="Tuned-2.3.3.2"><span class="toc-item-num">2.3.3.2&nbsp;&nbsp;</span>Tuned</a></span></li></ul></li><li><span><a href="#LightGBM" data-toc-modified-id="LightGBM-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>LightGBM</a></span><ul class="toc-item"><li><span><a href="#Base" data-toc-modified-id="Base-2.3.4.1"><span class="toc-item-num">2.3.4.1&nbsp;&nbsp;</span>Base</a></span></li><li><span><a href="#Tuned" data-toc-modified-id="Tuned-2.3.4.2"><span class="toc-item-num">2.3.4.2&nbsp;&nbsp;</span>Tuned</a></span></li></ul></li><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>CatBoost</a></span><ul class="toc-item"><li><span><a href="#Base" data-toc-modified-id="Base-2.3.5.1"><span class="toc-item-num">2.3.5.1&nbsp;&nbsp;</span>Base</a></span></li><li><span><a href="#Tuned" data-toc-modified-id="Tuned-2.3.5.2"><span class="toc-item-num">2.3.5.2&nbsp;&nbsp;</span>Tuned</a></span></li></ul></li><li><span><a href="#Results" data-toc-modified-id="Results-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#LGB--chosen-model" data-toc-modified-id="LGB--chosen-model-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>LGB- chosen model</a></span><ul class="toc-item"><li><span><a href="#Features'-importances" data-toc-modified-id="Features'-importances-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Features' importances</a></span></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="#Sanity-check" data-toc-modified-id="Sanity-check-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Sanity check</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Data
# ## Project description
# Sweet Lift Taxi company has collected historical data on taxi orders at airports. To attract more drivers during peak hours, we need to predict amount of taxi orders for next hour. Build a model for such a prediction.
# RMSE metric on test set should not be more than 48.
#
# ## Data description
# **Features**
# - `datetime`— observation time stamp.
#
# **Target**
# - `num_orders`- number of taxi orders at particular time stamp.

# %% [markdown]
# ## Library imports and project environment setup

# %%
#Data preprocessing and manipulation
import pandas as pd
import numpy as np

#Remove warnings
import sys
import warnings
if not sys.warnoptions:
   warnings.simplefilter("ignore");

#Stats
from statsmodels.tsa.seasonal import seasonal_decompose

#EDA and visualization
import matplotlib.pyplot as plt
import seaborn as sns

#ML
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler as ss
from xgboost import XGBRegressor

# %% [markdown]
# ## CSV file read

# %%
#Reading csv file using try-except to handle unexpected errors
try:
    df=pd.read_csv('/Downloads/taxi.csv', index_col=[0], parse_dates=[0])

except:
    df=pd.read_csv('https://code.s3.yandex.net/datasets/taxi.csv', index_col=[0], parse_dates=[0])

# %% [markdown]
# ## General info

# %%
#Printing first five entries in dataframe
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %% [markdown]
# - Datetime chronological order needs to be checked.
# - Data needs to be resampled by 1 hour to predict orders for next hour.
# - Data needs to be checkd for duplicates.

# %%
#General file examination (missing values and data types)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# - Dataset includes 26496 entries, 1 feature (index) and 1 numeric target column (regression task).
# - There aren't any missing values.
# - `Age` data type should be converted to integer.
# - Data from March 2018 to August 2018- 6 months in total.

# %%
#Integrated display of columns
df.describe(include='all')
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %% [markdown]
# - Avg. number of orders is 14.
# - Target has max. value of 119 and min. of 0.

# %% [markdown]
# ## Preprocessing

# %%
#Duplicates
df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates.

# %%
#Chronological order
df.sort_index(inplace=True)
df.index.is_monotonic
# Out:
# True

# %% [markdown]
# Datetime is in chronological order.

# %%
#Resampling
df = df.resample('1H').sum()
df['mean'] = df['num_orders'].rolling(15).mean()
df['std'] = df['num_orders'].rolling(15).std()

#Plotting
df.plot(figsize=(8,4), title='Taxi orders- 2018');

# %% [markdown]
# Plot depicts STD barely changes over time. However avg. increases by a factor of 2. This stochastic process is slightly nonstationary.

# %%
#Dropping unnecessary columns we used for plot above
df = df.drop(['mean','std'], axis=1)

# %% [markdown]
# ## EDA

# %%
#Seasonal decomposition to see if there are any trends or seasonality
decomposed = seasonal_decompose(df)

plt.figure(figsize=(20, 12))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# - Trend plot depicts number of orders growing over time.
#
# - No clear seasonality maybe due to data only collected for 6 months.
#
# - Residuals plot depicts a stationary stochastic process, residuals' level stays the same, not impacting predictions. It is basically just noise in data. Level is mainly around 0, meaning data was successfully decomposed.

# %%
#Plotting hourly data and see if there are any patterns
plt.figure(figsize=(20, 6))
decomposed.seasonal['2018-03-01':'2018-03-15'].plot()
plt.title('Hourly taxi orders');

# %% [markdown]
# Plot depicts clear pattern of daily orders with same high and low peaks daily.

# %% [markdown]
# ## New features

# %%
#Creating new features to help model make better predictions 
def make_features(data, max_lag, rolling_mean_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hourofday'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    #data['rolling_std'] = data['num_orders'].shift().rolling(rolling_mean_size).std()
    
make_features(df, 10, 5)

df.head()
# Out:
#                      num_orders  month  day  dayofweek  hourofday  lag_1  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3          0    NaN
# 2018-03-01 01:00:00          85      3    1          3          1  124.0
# 2018-03-01 02:00:00          71      3    1          3          2   85.0
# 2018-03-01 03:00:00          66      3    1          3          3   71.0
# 2018-03-01 04:00:00          43      3    1          3          4   66.0
#
#                      lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  lag_9  \
# datetime
# 2018-03-01 00:00:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2018-03-01 02:00:00  124.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2018-03-01 03:00:00   85.0  124.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2018-03-01 04:00:00   71.0   85.0  124.0    NaN    NaN    NaN    NaN    NaN
#
#                      lag_10  rolling_mean
# ...

# %% [markdown]
# # Model
# ## Splitting

# %%
df = df.dropna(how='any', axis=0)

X = df.drop('num_orders', axis=1)
y = df['num_orders']

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.1)

print('Train set from', X_train.index.min(), 'until', X_train.index.max())
print('Test set from', X_test.index.min(), 'until', X_test.index.max())
# Out:
# Train set from 2018-03-01 10:00:00 until 2018-08-13 14:00:00
# Test set from 2018-08-13 15:00:00 until 2018-08-31 23:00:00

# %% [markdown]
# ## Standard scaling

# %%
sc = ss()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Model selection by RMSE

# %%
#Creating function and scorer for GridSearch and cross-validation
def rmse(actual, predict):
    predict = np.array(predict)
    actual = np.array(actual)

    distance = predict - actual

    square_distance = distance ** 2

    mean_square_distance = square_distance.mean()

    score = np.sqrt(mean_square_distance)

    return score

rmse_scorer = make_scorer(rmse, greater_is_better = False)

# %%
#TimeSeriesSplit for models to split train set into train and validation sets
tscv = TimeSeriesSplit()

# %% [markdown]
# ### Baseline

# %%
model = DummyRegressor(strategy='median')
baseline = np.mean(abs(cross_val_score(model,  X_train, y_train, cv=tscv, scoring = rmse_scorer)))
baseline
# Out:
# 41.598174732872344

# %% [markdown]
# ### Random Forest
# #### Base

# %%
RF = RandomForestRegressor(random_state=12345)
RF_base = np.mean(abs(cross_val_score(RF,  X_train, y_train, cv=tscv, scoring = rmse_scorer)))
RF_base
# Out:
# 25.32352714620074

# %% [markdown]
# #### Tuned

# %%
params = {"n_estimators" : [500, 700],
             "max_depth" : [6, 7, 8, 9, 10]}

gsSVR = GridSearchCV(estimator=RF, cv=tscv, param_grid=params, n_jobs=-1, verbose=0, scoring=rmse_scorer)
gsSVR.fit(X_train, y_train)
SVR_best = gsSVR.best_estimator_

best_param = pd.DataFrame(gsSVR.best_params_, index=[0])
RF_score_tuned = abs(gsSVR.best_score_)
best_param['score'] = RF_score_tuned

best_param
# Out:
#    max_depth  n_estimators      score
# 0         10           500  25.581236

# %% [markdown]
# ### XGBoost
# #### Base

# %%
XGB = XGBRegressor(n_jobs=-1, random_state=12345)
XGB_base = np.mean(abs(cross_val_score(XGB,  X_train, y_train, cv=tscv, scoring = rmse_scorer)))
XGB_base
# Out:
# 26.342644199876226

# %% [markdown]
# #### Tuned

# %%
params = {"n_estimators" : [500, 700],
             "max_depth" : [6, 7, 8, 9, 10]}

gsSVR = GridSearchCV(estimator=XGB, cv=tscv, param_grid=params, n_jobs=-1, verbose=0, scoring=rmse_scorer)
gsSVR.fit(X_train, y_train)
SVR_best = gsSVR.best_estimator_

best_param = pd.DataFrame(gsSVR.best_params_, index=[0])
XGB_score_tuned = abs(gsSVR.best_score_)
best_param['score'] = XGB_score_tuned

best_param
# Out:
#    max_depth  n_estimators      score
# 0          6           500  26.353316

# %% [markdown]
# ### LightGBM
# #### Base

# %%
LGB = LGBMRegressor(random_state=12345)
LGB_base = np.mean(abs(cross_val_score(LGB,  X_train, y_train, cv=tscv, scoring = rmse_scorer)))
LGB_base
# Out:
# 25.015587098660365

# %% [markdown]
# #### Tuned

# %%
params = {"n_estimators" : [500, 700],
             "max_depth" : [6, 7, 8, 9, 10]}

gsSVR = GridSearchCV(estimator=LGB, cv=tscv, param_grid=params, n_jobs=-1, verbose=0, scoring=rmse_scorer)
gsSVR.fit(X_train, y_train)
SVR_best = gsSVR.best_estimator_

best_param = pd.DataFrame(gsSVR.best_params_, index=[0])
LGB_score_tuned = abs(gsSVR.best_score_)
best_param['score'] = LGB_score_tuned

best_param
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
#    max_depth  n_estimators      score
# 0         10           500  25.540662

# %% [markdown]
# ### CatBoost
# #### Base

# %%
CB = CatBoostRegressor(verbose=0, loss_function="RMSE", random_state=12345)
CB_base = np.mean(abs(cross_val_score(CB,  X_train, y_train, cv=tscv, scoring = rmse_scorer)))
CB_base
# Out:
# 25.17364681112341

# %% [markdown]
# #### Tuned

# %%
params = {"iterations" : [500, 700],
             "depth" : [6, 7, 8, 9, 10]}

gsSVR = GridSearchCV(estimator=CB, cv=tscv, param_grid=params, n_jobs=-1, verbose=0, scoring=rmse_scorer)
gsSVR.fit(X_train, y_train)
SVR_best = gsSVR.best_estimator_

best_param = pd.DataFrame(gsSVR.best_params_, index=[0])
CB_score_tuned = abs(gsSVR.best_score_)
best_param['score'] = CB_score_tuned

best_param
# Out:
#    depth  iterations     score
# 0      6         500  25.16201

# %% [markdown]
# ### Results

# %%
#Plotting model scores
models = pd.DataFrame({
    'Model': ['baseline', 'RF_base', 'XGB_base', 'LGB_base', 'CB_base', 
             'RF_tuned', 'XGB_tuned', 'LGB_tuned', 'CB_tuned'],
    'Score': [baseline, RF_base, XGB_base, LGB_base, CB_base,
             RF_score_tuned, XGB_score_tuned, LGB_score_tuned, CB_score_tuned]})
sorted_by_score = models.sort_values(by='Score', ascending=False)

sns.barplot(x='Score', y = 'Model', data = sorted_by_score, color = 'g')
plt.title('ML models')
plt.xlabel('RMSE- test data (%)')
plt.ylabel('Model');

# %% [markdown]
# Plot depicts LGB_base has best train RMSE (25.015).

# %% [markdown]
# ## LGB- chosen model
# ### Features' importances

# %%
#Finding features' importances for prediction
LGB = LGBMRegressor(random_state=12345)
LGB.fit(X_train, y_train)

LGB_feature_importance = pd.Series(LGB.feature_importances_, df.drop(['num_orders'], axis=1).columns).sort_values(ascending=True)
plt.barh(LGB_feature_importance.index, LGB_feature_importance)
plt.xlabel("LightGBM Feature Importance");

# %% [markdown]
# `hourofday` is most important feature.

# %% [markdown]
# ### Testing

# %%
y_pred_test = LGB.predict(X_test)
LGB_test_score = rmse(y_test, y_pred_test)
LGB_test_score
# Out:
# 43.30987084302385

# %%
round((LGB_test_score-LGB_base)/LGB_test_score * 100, 2)
# Out:
# 42.24

# %% [markdown]
# Test score is 42.24% higher than train score, maybe due to slight overfitting. This leaves room for future improvement, yet target of 48 or lower has been met.

# %% [markdown]
# ### Sanity check

# %%
model = DummyRegressor(strategy='median')
model.fit(X_train, y_train)
y_base_test = model.predict(X_test)
base_test_score = rmse(y_test, y_base_test)
base_test_score
# Out:
# 87.24205906985632

# %%
round((base_test_score-LGB_test_score)/base_test_score * 100, 2)
# Out:
# 50.36

# %% [markdown]
# Final CatBoost test score is 50.36% lower than dummy baseline, meaning modeling was useful.

# %%
plt.figure(figsize=(10,3))
y_test.plot(label='y_test')
pd.Series(y_pred_test, index=y_test.index).plot(label='prediction')
plt.title('y_test vs prediction')
plt.legend()
plt.show()

# %% [markdown]
# # Conclusion
#
# In summary, in this project we developed a model to determine amount of taxi orders for next hour based on historical data. RMSE metric on test set had to be no more than 48.
#
# <ins>We followed the methodology as follows:<ins>
# - Open data file and study general information.
# - Data preprocessing.
# - Exploratory data analysis.
# - Encoding.
# - Splitting into train and test sets.
# - Standard scaling.
# - Modeling and model selection by RMSE.
# - Finding features' importances.
# - Sanity check.
# - And now, final conclusion.
#
# <ins>Findings:<ins>
# - `hourofday` is most important feature.
# - Base LightGBM model has lowest RMSE score.
# - Final LightGBM test score (43.309) is 50.36% lower than dummy baseline (87.242), meaning modeling was useful.
